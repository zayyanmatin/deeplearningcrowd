# %%
# Import the packages we'll use

import numpy as np
import os, glob, csv

import tensorflow as tf
# # librosa is a widely-used audio processing library
import librosa

import sklearn
import os
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms

from torch.utils.data import Dataset
from torchaudio import transforms as t
import pandas as pd
import torchaudio
import torch
import torch.nn as nn
import torch.nn.functional as nnF

# # for plotting
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
os.getcwd()
# Out:
# '/Users/zayyanmatin/Desktop/Masters/DLAM'

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cpu

# %%
os.listdir()
# Out:
# ['non project stuff',
#  'Pytorch_Audio_Classifier_Procedure_Raw-Copy1.ipynb',
#  'Pytorch_Audio_Classifier_Procedure-Testing.ipynb',
#  'Pytorch_Audio_Classifier_Procedure_Raw-Copy3.ipynb',
#  'Untitled1.ipynb',
#  'test1.rtf',
#  'Pytorch_Audio_Classifier_Procedure_Mel-Copy1.ipynb',
#  '.DS_Store',
#  'bgBinary.csv',
#  'Pytorch_Audio_Classifier_Procedure_Raw-Copy2.ipynb',
#  'Untitled.ipynb',
#  'bird_bg04.wav',
#  'bg_class.csv',
#  'Pytorch_Audio_Classifier_Procedure_Mel-Copy2.ipynb',
#  'bgBinary 2.numbers',
#  'other projects',
#  'bgBinary_Crowd.csv',
#  'Training_Validation_Maker.ipynb',
#  'bgBinary.numbers',
#  'env',
#  'Pytorch_Audio_Classifier_Procedure_Fusion.ipynb',
#  'WaveNet-master ',
#  'raw.pt',
#  '.ipynb_checkpoints',
#  'tensorflow-wavenet-master',
#  'Isolated_urban_sound_database',
#  'Pytorch_Audio_Classifier_Procedure_Raw.ipynb',
#  'Pytorch_Audio_Classifier_Procedure_Mel.ipynb']

# %%
csvData = pd.read_csv('./bgBinary_Crowd.csv')
print(len(csvData))
print(csvData.iloc[80,2])
# Out:
# 162
# 0

# %%
class UrbanSoundDataset(Dataset):
#rapper for the UrbanSound8K dataset
    # Argument List
    #  path to the UrbanSound8K csv file
    #  path to the UrbanSound8K audio files
    #  list of folders to use in the dataset
    
    def __init__(self, csv_path, file_path, folderList):
        csvData = pd.read_csv(csv_path)
        #initialize lists to hold file names, labels, and folder numbers
        self.file_names = []
        self.labels = []
        self.folders = []
        #loop through the csv entries and only add entries from folders in the folder list
        for i in range(0,len(csvData)):
            if csvData.iloc[i, 3] in folderList:
                self.file_names.append(csvData.iloc[i, 0])
                self.labels.append(csvData.iloc[i, 2])
                self.folders.append(csvData.iloc[i, 3])
                
        self.file_path = file_path
        self.mixer = torch.mean #Two channels will convert to one
        self.folderList = folderList
        
    def __getitem__(self, index):
        #format the file path and load the file
        path = self.file_path + "fold" + str(self.folders[index]) + "/" + self.file_names[index]
        
        #load returns a tensor with the sound data and the sampling frequency (44.1kHz)
        sound = torchaudio.load(path, out = None, normalization = True)

        soundData = torch.mean(sound[0], 0, keepdim=False, out=None)
        
        
        soundData = soundData.unsqueeze_(-1)

        
        #downsample the audio to ~8kHz
        tempData = torch.zeros([160000, 1]) #tempData accounts for audio clips that are too short
        
        if soundData.numel() < 160000:
            tempData[:soundData.numel()] = soundData[:]
        else:
            tempData[:] = soundData[:160000]
        
        soundData = tempData
        
        soundFormatted = torch.zeros([32000, 1])
        soundFormatted[:32000] = soundData[::5] #take every fifth sample of soundData
        soundFormatted2 = soundFormatted.squeeze(-1)
        soundMel = torchaudio.transforms.MFCC(sound[1]/5)(soundFormatted2)
        soundMel = soundMel.unsqueeze_(0)
#         soundMel = soundMel.permute(1, 0,2)

        
        
        return soundFormatted, soundMel, self.labels[index]
    
    def __len__(self):
        return len(self.file_names)

    
csv_path = './bgBinary_Crowd.csv'
file_path = './Isolated_urban_sound_database/'

train_set = UrbanSoundDataset(csv_path, file_path, range(0,4))
test_set = UrbanSoundDataset(csv_path, file_path, [4])
print("Train set size: " + str(len(train_set)))
print("Test set size: " + str(len(test_set)))

kwargs = {'num_workers': 1, 'pin_memory': True} if device == 'cuda' else {} #needed for using datasets on gpu

train_loader = torch.utils.data.DataLoader(train_set, batch_size = 32, shuffle = True, **kwargs)
test_loader = torch.utils.data.DataLoader(test_set, batch_size = 32, shuffle = True, **kwargs)
# Out:
# Train set size: 130
# Test set size: 32

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv1d(1, 128, 80, 4)
        self.bn1 = nn.BatchNorm1d(128)
        self.pool1 = nn.MaxPool1d(4)
        self.conv2 = nn.Conv1d(128, 128, 3)
        self.bn2 = nn.BatchNorm1d(128)
        self.pool2 = nn.MaxPool1d(4)
        self.conv3 = nn.Conv1d(128, 256, 3)
        self.bn3 = nn.BatchNorm1d(256)
        self.pool3 = nn.MaxPool1d(4)
        self.conv4 = nn.Conv1d(256, 512, 3)
        self.bn4 = nn.BatchNorm1d(512)
        self.pool4 = nn.MaxPool1d(4)
        self.avgPool = nn.AvgPool1d(30) #input should be 512x30 so this outputs a 512x1
        self.fc1 = nn.Linear(512, 10)
        
    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(self.bn1(x))
        x = self.pool1(x)
        x = self.conv2(x)
        x = F.relu(self.bn2(x))
        x = self.pool2(x)
        x = self.conv3(x)
        x = F.relu(self.bn3(x))
        x = self.pool3(x)
        x = self.conv4(x)
        x = F.relu(self.bn4(x))
        x = self.pool4(x)
        x = self.avgPool(x)
        x = x.permute(0, 2, 1) #change the 512x1 to 1x512
        x = self.fc1(x)
        return F.log_softmax(x, dim = 2)

modelA = Net()
modelA.load_state_dict(torch.load('./raw.pt'))
#freeze parameters
for param in modelA.parameters():
    param.requires_grad_(False)
modelA.to(device)

print(modelA)
# Out:
# Net(
#   (conv1): Conv1d(1, 128, kernel_size=(80,), stride=(4,))
#   (bn1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool1): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (conv2): Conv1d(128, 128, kernel_size=(3,), stride=(1,))
#   (bn2): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool2): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv1d(128, 256, kernel_size=(3,), stride=(1,))
#   (bn3): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool3): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (conv4): Conv1d(256, 512, kernel_size=(3,), stride=(1,))
#   (bn4): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (pool4): MaxPool1d(kernel_size=4, stride=4, padding=0, dilation=1, ceil_mode=False)
#   (avgPool): AvgPool1d(kernel_size=(30,), stride=(30,), padding=(0,))
#   (fc1): Linear(in_features=512, out_features=10, bias=True)
# )

# %%
class CnnAudioNet(nn.Module):
    def __init__(self):
        super(CnnAudioNet,self).__init__()

        self.Fc_features = 40
        self.C1 = nn.Conv2d(1,32,3,padding=1)
        self.C2 = nn.Conv2d(32,64,3,padding=1)
        self.C3 = nn.Conv2d(64,64,3,padding=1)
        self.C4 = nn.Conv2d(64,64,3,padding=1)
        self.C5 = nn.Conv2d(64,64,3,padding=1)
        
        self.BN1 = nn.BatchNorm2d(32)
        self.BN2 = nn.BatchNorm2d(64)
        self.BN3 = nn.BatchNorm2d(64)
        self.maxpool1 = nn.MaxPool2d(2,2)
        self.maxpool2 = nn.MaxPool2d((1,2),(1,2))
        
        
        self.fc1 = nn.Linear(64*1*5,128)
        self.fc2 = nn.Linear(128,10)
        self.dropout = nn.Dropout(0.25)
        self.Bat1 = nn.BatchNorm1d(128)

        
        
    def forward(self,x):
        # add sequence of convolutional and max pooling layers
        x = self.C1(x)
        x = self.BN1(x)
        x = self.maxpool1(x)
        x = self.maxpool1(F.relu(self.BN2(self.C2(x))))
        x = self.maxpool1(F.relu(self.BN2(self.C3(x))))
        x = self.maxpool1(F.relu(self.BN3(self.C4(x))))
        x = self.maxpool1(F.relu(self.BN3(self.C5(x))))
        # flatten image input
        x =x.permute(0,2,1,3)
        x=torch.flatten(x, start_dim=2, end_dim=3)
        # add dropout layer
        x =  self.dropout(self.fc1(x))
        x = F.log_softmax(self.fc2(x),  dim =2)

        return x
        
modelB = CnnAudioNet()
modelB.load_state_dict(torch.load('./mel.pt'))
for param in modelB.parameters():
    param.requires_grad_(False)
modelB.to(device)
print(modelB)
# Out:
# CnnAudioNet(
#   (C1): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (C2): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (C3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (C4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (C5): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (BN1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxpool1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (maxpool2): MaxPool2d(kernel_size=(1, 2), stride=(1, 2), padding=0, dilation=1, ceil_mode=False)
#   (fc1): Linear(in_features=320, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=10, bias=True)
#   (dropout): Dropout(p=0.25, inplace=False)
#   (Bat1): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %%
class MyEnsemble(nn.Module):
    def __init__(self, modelA, modelB, nb_classes=10):
        super(MyEnsemble, self).__init__()
        self.modelA = modelA
        self.modelB = modelB
        # Remove last linear layer
        self.modelA.fc1 = nn.Identity()
        self.modelB.fc2 = nn.Identity()
        
        # Create new classifier
        self.classifier = nn.Linear(128+512, 10)
        
    def forward(self, x, y):
        print("X" + str(x.shape))
        print("Y" + str(y.shape))
        x=x.permute(0,2,1)
        x1 = self.modelA(x.clone())  # clone to make sure x is not changed by inplace methods
        x1 = x1.view(x1.size(0), -1)
        print("X1" + str(x1.shape))

        y2 = self.modelB(y.clone())
        y2 = y2.view(y2.size(0), -1)
        print("Y2" + str(y2.shape))
        
        z = torch.cat((x1, y2), dim=1)
        print("Z" + str(z.shape))
#         z = self.classifier(z)
        print("ZLinear" + str(z.shape))
        z = F.log_softmax(self.classifier(z),  dim =1)
        print("ZLinear2" + str(z.shape))
        return z

# Create ensemble model
model = MyEnsemble(modelA, modelB)

# x = torch.randn(1, 3, 224, 224)
# output = model(x)

# %%
optimizer = optim.Adam(model.parameters(), lr = 0.001, weight_decay = 0.0001)

# %%
def train(model, epoch):
    model.train()
    for batch_idx, (dataA,dataB, target) in enumerate(train_loader):
        optimizer.zero_grad()
        dataA = dataA.to(device)
        dataB = dataB.to(device)
        target = target.to(device)
        dataA = dataA.requires_grad_() #set requires_grad to True for training
        dataB = dataB.requires_grad_() #set requires_grad to True for training        
        output = model(dataA,dataB)
#         output = output.permute(1, 0, 2)
#         output = output.unsqueeze(1)
        print("LossOutPre" + str(output.shape))
#         print("LossOut" + str(output[0].shape))
#         print("LossOut" + str(output[0][1]))
        loss = F.nll_loss(output, target) #the loss functions expects a batchSizex10 input
        loss.backward()
        optimizer.step()
        if batch_idx % log_interval == 0: #print training stats
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(dataA), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss))

        
    if loss <= 0.00010:
        
        return 1
    
    else:
        return 0

# %%
def test(model, epoch):
    model.eval()
    correct = 0
    for dataA, dataB, target in test_loader:
        dataA = dataA.to(device)
        dataB = dataB.to(device)
        target = target.to(device)
        output = model(dataA,dataB)
        output = output.permute(1, 0, 2)
        output = output.unsqueeze(0)
        pred = output.max(2)[1] # get the index of the max log-probability
        correct += pred.eq(target).cpu().sum().item()
    print('\nTest set: Accuracy: {}/{} ({:.0f}%)\n'.format(
        correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))

# %%
log_interval = 2
for epoch in range(1, 27):
    if epoch == 31:
        print("First round of training complete. Setting learn rate to 0.001.")
    
    train(model, epoch)
    test(model, epoch)
# Out:
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 1 [0/130 (0%)]	Loss: 0.274805
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 1 [64/130 (40%)]	Loss: 0.388388
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 1 [8/130 (80%)]	Loss: 0.273092
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 2 [0/130 (0%)]	Loss: 0.214319
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 2 [64/130 (40%)]	Loss: 0.688791
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 2 [8/130 (80%)]	Loss: 0.001606
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 3 [0/130 (0%)]	Loss: 0.357561
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 3 [64/130 (40%)]	Loss: 0.319610
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 3 [8/130 (80%)]	Loss: 0.035003
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 4 [0/130 (0%)]	Loss: 0.202981
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 4 [64/130 (40%)]	Loss: 0.360292
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 4 [8/130 (80%)]	Loss: 0.114742
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 5 [0/130 (0%)]	Loss: 0.210542
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 5 [64/130 (40%)]	Loss: 0.743247
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 5 [8/130 (80%)]	Loss: 0.006310
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 6 [0/130 (0%)]	Loss: 0.207176
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 6 [64/130 (40%)]	Loss: 0.122862
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 6 [8/130 (80%)]	Loss: 0.192880
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 7 [0/130 (0%)]	Loss: 0.248433
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 7 [64/130 (40%)]	Loss: 0.455827
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 7 [8/130 (80%)]	Loss: 0.024380
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 8 [0/130 (0%)]	Loss: 0.453853
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 8 [64/130 (40%)]	Loss: 0.148736
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 8 [8/130 (80%)]	Loss: 0.164755
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 9 [0/130 (0%)]	Loss: 0.158808
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 9 [64/130 (40%)]	Loss: 0.197045
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 9 [8/130 (80%)]	Loss: 1.433169
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 10 [0/130 (0%)]	Loss: 0.378303
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 10 [64/130 (40%)]	Loss: 0.306420
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 10 [8/130 (80%)]	Loss: 0.007923
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 11 [0/130 (0%)]	Loss: 0.310723
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 11 [64/130 (40%)]	Loss: 0.000345
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 11 [8/130 (80%)]	Loss: 0.000050
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 12 [0/130 (0%)]	Loss: 0.391427
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 12 [64/130 (40%)]	Loss: 0.478971
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 12 [8/130 (80%)]	Loss: 0.010827
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 13 [0/130 (0%)]	Loss: 0.342244
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 13 [64/130 (40%)]	Loss: 0.245769
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 13 [8/130 (80%)]	Loss: 0.027016
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 14 [0/130 (0%)]	Loss: 0.359958
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 14 [64/130 (40%)]	Loss: 0.857999
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 14 [8/130 (80%)]	Loss: 0.000760
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 15 [0/130 (0%)]	Loss: 0.553045
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 15 [64/130 (40%)]	Loss: 0.257969
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 15 [8/130 (80%)]	Loss: 0.125930
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 16 [0/130 (0%)]	Loss: 0.262493
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 16 [64/130 (40%)]	Loss: 0.178772
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 16 [8/130 (80%)]	Loss: 0.019570
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 17 [0/130 (0%)]	Loss: 0.160872
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 17 [64/130 (40%)]	Loss: 0.356007
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 17 [8/130 (80%)]	Loss: 0.017386
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 18 [0/130 (0%)]	Loss: 0.174561
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 18 [64/130 (40%)]	Loss: 0.215174
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 18 [8/130 (80%)]	Loss: 0.111523
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 19 [0/130 (0%)]	Loss: 0.243916
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 19 [64/130 (40%)]	Loss: 0.008637
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 19 [8/130 (80%)]	Loss: 0.009091
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 20 [0/130 (0%)]	Loss: 0.075482
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 20 [64/130 (40%)]	Loss: 0.279906
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 20 [8/130 (80%)]	Loss: 0.044170
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 29/32 (91%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 21 [0/130 (0%)]	Loss: 0.218441
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 21 [64/130 (40%)]	Loss: 0.197848
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 21 [8/130 (80%)]	Loss: 0.008033
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 22 [0/130 (0%)]	Loss: 0.411911
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 22 [64/130 (40%)]	Loss: 0.591507
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 22 [8/130 (80%)]	Loss: 0.003966
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 23 [0/130 (0%)]	Loss: 0.106270
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 23 [64/130 (40%)]	Loss: 0.062196
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 23 [8/130 (80%)]	Loss: 0.637044
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 11/32 (34%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 24 [0/130 (0%)]	Loss: 0.827144
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 24 [64/130 (40%)]	Loss: 0.199751
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 24 [8/130 (80%)]	Loss: 4.090574
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 25 [0/130 (0%)]	Loss: 0.787363
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 25 [64/130 (40%)]	Loss: 0.271429
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 25 [8/130 (80%)]	Loss: 0.001768
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
#
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 26 [0/130 (0%)]	Loss: 0.132955
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Train Epoch: 26 [64/130 (40%)]	Loss: 0.302700
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
# LossOutPretorch.Size([32, 10])
# Xtorch.Size([2, 32000, 1])
# Ytorch.Size([2, 1, 40, 161])
# X1torch.Size([2, 512])
# Y2torch.Size([2, 128])
# Ztorch.Size([2, 640])
# ZLineartorch.Size([2, 640])
# ZLinear2torch.Size([2, 10])
# LossOutPretorch.Size([2, 10])
# Train Epoch: 26 [8/130 (80%)]	Loss: 0.020619
# Xtorch.Size([32, 32000, 1])
# Ytorch.Size([32, 1, 40, 161])
# X1torch.Size([32, 512])
# Y2torch.Size([32, 128])
# Ztorch.Size([32, 640])
# ZLineartorch.Size([32, 640])
# ZLinear2torch.Size([32, 10])
#
# Test set: Accuracy: 27/32 (84%)
